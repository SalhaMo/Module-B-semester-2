# %% [markdown]
# # Week 6 - Bivariate Analysis, part 2

# %% [markdown]
# # 1. Lesson: no lesson this week

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Suppose you wanted to show the nitrate and phosphate level in a water sample.  What are the advantages and disadvantages of showing this as an area plot, as opposed to two separate line graphs?  How would you adjust the graphs shown to improve the presentation?

# %%
# !pip install -q matplotlib
# !pip install -q numpy
# !pip install -q seaborn
# !pip install -q pandas
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='ME')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series_2 =  100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='ME')
ax = sns.lineplot(x = datearray, y = time_series_2)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %%
df = pd.DataFrame({'ser1': time_series, 'ser2': time_series_2}, index = datearray)
df.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# ### Here are some types of analysis you can do:
#
# - Find correlations between pairs of variables.
#
# - Draw scatterplots, especially when the correlation is large.
#
# - Draw pairplots.
#
# - Draw line graphs and/or area graphs when there is date or time data together with numerical data.
#
# ### Conclusions:
#
# - Explain what conclusions you would draw from this analysis: are the data what you expect?  Are the data likely to be usable?  If the data are not useable, find some new data!
#
# - Do you see any outliers?  (Data points that are far from the rest of the data).
#
# - Are any data items highly correlated with each other, suggesting that they are redundant?
#
# - For the line plots, do you see a trend or pattern over time?  Does this suggest that the data are changing over time (drifting) in such a way as to invalidate comparisons?
#
# - Can you think of any confounding variables?  (Third variables that could explain any correlations between other variables.  These third variables may or may not be reported in the dataset.)

# %%
df= pd.read_csv('state.csv',sep=',')
df.head()
# Out:
#    year stabbr  state_name  statefip region4             region9    effort  \
# 0  2022     AL     Alabama         1   South  East South Central  0.036929
# 1  2022     AK      Alaska         2    West             Pacific  0.043423
# 2  2022     AZ     Arizona         4    West            Mountain  0.024628
# 3  2022     AR    Arkansas         5   South  West South Central  0.038394
# 4  2022     CA  California         6    West             Pacific  0.030721
#
#    inc_effort  predicted_fedrevpp0_  predicted_fedrevpp10_  ...  \
# 0    0.039076              1108.649               1668.692  ...
# 1    0.056036              1776.774               3541.949  ...
# 2    0.026759              1067.853               1859.725  ...
# 3    0.037691              1381.248               2004.317  ...
# 4    0.036699              1214.363               2042.963  ...
#
#    inc_gap130_ratio  coverage  state_chartershare  inc_pubsch  inc_nonpubsch  \
# ...

# %%
df= df.query('year >=2000')

# %%
df.describe()
# Out:
#               year     statefip      effort   inc_effort  \
# count  1173.000000  1173.000000  862.000000  1066.000000
# mean   2011.000000    28.960784    0.036511     0.043243
# std       6.636079    15.683522    0.006322     0.007179
# min    2000.000000     1.000000    0.015759     0.025232
# 25%    2005.000000    16.000000    0.031993     0.038843
# 50%    2011.000000    29.000000    0.036168     0.042439
# 75%    2017.000000    42.000000    0.040870     0.047094
# max    2022.000000    56.000000    0.055217     0.073341
#
#        predicted_fedrevpp0_  predicted_fedrevpp10_  predicted_fedrevpp20_  \
# count           1127.000000            1127.000000            1127.000000
# mean             438.515297             737.478163            1292.118873
# std              274.236684             405.283945             743.945208
# min               59.638490             146.113600             246.826000
# 25%              269.042000             498.280800             870.966650
# ...

# %%
df.columns
# Out:
# Index(['year', 'stabbr', 'state_name', 'statefip', 'region4', 'region9',
#        'effort', 'inc_effort', 'predicted_fedrevpp0_', 'predicted_fedrevpp10_',
#        ...
#        'inc_gap130_ratio', 'coverage', 'state_chartershare', 'inc_pubsch',
#        'inc_nonpubsch', 'pubprv_incratio', 'case', 'citation', 'ruling',
#        'casetype'],
#       dtype='str', length=124)

# %%
df= df[['state_name','ec_enrollgapratio','fairness_strevpp','necm_fundinggap_state','year']]

# %%
plt.hist(df['fairness_strevpp'])
# Out:
# (array([1.116e+03, 7.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  0.4687594 ,  33.86633346,  67.26390752, 100.66148158,
#         134.05905564, 167.4566297 , 200.85420376, 234.25177782,
#         267.64935188, 301.04692594, 334.4445    ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df['fairness_strevpp'])
# Out:
# <Axes: ylabel='fairness_strevpp'>

# %%
df['fairness_log'] = np.log1p(df['fairness_strevpp'])

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# Original variable
sns.histplot(df['fairness_strevpp'], bins=30, ax=axes[0])
axes[0].set_title('State Revenue Progressivity')
axes[0].set_xlabel('fairness_strevpp')
axes[0].set_ylabel('Count')

# Log transformed variable
sns.histplot(df['fairness_log'], bins=30, ax=axes[1])
axes[1].set_title('Log-Transformed Progressivity')
axes[1].set_xlabel('fairness_log')
axes[1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
df.sort_values('fairness_strevpp', ascending=False).head(20)
# Out:
#      state_name  ec_enrollgapratio  fairness_strevpp  necm_fundinggap_state  \
# 968     Wyoming           1.036109         334.44450                    NaN
# 1121    Wyoming           0.921782         105.19940                    NaN
# 407     Wyoming           1.249239          96.04358               8030.962
# 764     Wyoming           0.578071          93.33980                    NaN
# 1019    Wyoming           0.975595          65.42767                    NaN
# 1070    Wyoming           0.844171          55.45300                    NaN
# 866     Wyoming           1.009214          48.89585                    NaN
# 815     Wyoming           1.045326          45.66342                    NaN
# 917     Wyoming           1.048556          45.43183                    NaN
# 509     Wyoming           1.147131          37.42138               8024.958
# 152     Wyoming           0.918214          34.71741               7673.789
# ...

# %%
df.hist(figsize=(20,20), bins=30)
# Out:
# array([[<Axes: title={'center': 'ec_enrollgapratio'}>,
#         <Axes: title={'center': 'fairness_strevpp'}>],
#        [<Axes: title={'center': 'necm_fundinggap_state'}>,
#         <Axes: title={'center': 'year'}>],
#        [<Axes: title={'center': 'fairness_log'}>, <Axes: >]], dtype=object)

# %%
df = df[df['fairness_strevpp'] < 10]

# %%
df.sort_values('necm_fundinggap_state').head(10)
# Out:
#       state_name  ec_enrollgapratio  fairness_strevpp  necm_fundinggap_state  \
# 387   New Jersey           0.898253          5.092305             -28664.170
# 483  Mississippi           0.890955          0.997650              -9651.266
# 24   Mississippi           0.817921          1.017748              -9487.149
# 228  Mississippi           0.931628          1.004878              -9471.953
# 381  Mississippi           0.979258          1.012295              -9221.860
# 177  Mississippi           0.934249          1.017043              -9138.042
# 330  Mississippi           0.908006          1.026997              -9103.358
# 279  Mississippi           0.908641          1.011270              -8959.815
# 534  Mississippi           1.040984          1.039131              -8934.891
# 75   Mississippi           0.817112          0.989636              -8921.261
#
#      year  fairness_log
# 387  2015      1.807026
# 483  2013      0.691972
# 24   2022      0.701982
# ...

# %%
df_clean = df[df['necm_fundinggap_state'] > -20000]

# %%
df_clean.sort_values('necm_fundinggap_state').head(10)
# Out:
#       state_name  ec_enrollgapratio  fairness_strevpp  necm_fundinggap_state  \
# 483  Mississippi           0.890955          0.997650              -9651.266
# 24   Mississippi           0.817921          1.017748              -9487.149
# 228  Mississippi           0.931628          1.004878              -9471.953
# 381  Mississippi           0.979258          1.012295              -9221.860
# 177  Mississippi           0.934249          1.017043              -9138.042
# 330  Mississippi           0.908006          1.026997              -9103.358
# 279  Mississippi           0.908641          1.011270              -8959.815
# 534  Mississippi           1.040984          1.039131              -8934.891
# 75   Mississippi           0.817112          0.989636              -8921.261
# 432  Mississippi           1.065217          1.006145              -8617.313
#
#      year  fairness_log
# 483  2013      0.691972
# 24   2022      0.701982
# 228  2018      0.695583
# ...

# %%
df_clean= df[['state_name','ec_enrollgapratio','fairness_log','necm_fundinggap_state']]

# %%
sns.pairplot(df_clean)

# %%
df[['ec_enrollgapratio','fairness_log','necm_fundinggap_state']].corr()
# Out:
#                        ec_enrollgapratio  fairness_log  necm_fundinggap_state
# ec_enrollgapratio               1.000000     -0.008922              -0.058806
# fairness_log                   -0.008922      1.000000               0.542049
# necm_fundinggap_state          -0.058806      0.542049               1.000000

# %%
df_year = df.groupby('year')[['ec_enrollgapratio','fairness_log','necm_fundinggap_state']].mean().reset_index()

plt.figure(figsize=(10,6))

sns.lineplot(data=df_year, x='year', y='ec_enrollgapratio', label='Enrollment Ratio')
sns.lineplot(data=df_year, x='year', y='fairness_log', label='Revenue Progressivity (log)')
sns.lineplot(data=df_year, x='year', y='necm_fundinggap_state', label='Funding Gap')

plt.title('Trends of Education and Fiscal Variables Over Time')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.legend()

plt.show()

# %%
fig, axes = plt.subplots(3,1, figsize=(10,10))

sns.lineplot(data=df_year, x='year', y='ec_enrollgapratio', ax=axes[0])
axes[0].set_title("Enrollment Ratio Over Time")

sns.lineplot(data=df_year, x='year', y='fairness_log', ax=axes[1])
axes[1].set_title("Revenue Progressivity (log)")

sns.lineplot(data=df_year, x='year', y='necm_fundinggap_state', ax=axes[2])
axes[2].set_title("Funding Adequacy Gap Over Time")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 86-98 of the Storytelling With Data book as best you can.  (The second half of chapter three).  You do not have to get the exact data values right, just the overall look and feel.

# %%
# import matplotlib.pyplot as plt
# import numpy as np
from matplotlib.patches import Patch

# Categories
categories = ["Price", "Convenience", "Relationship", "Service", "Selection"]

# Approximate values from the image
our_business = np.array([92, 88, 38, 18, 14])

competitors = {
    "Competitor A": np.array([83, 105, 100, 70, 112]),
    "Competitor B": np.array([58, 42, 40, 55, 28]),
    "Competitor C": np.array([72, 84, 62, 48, 66]),
    "Competitor D": np.array([44, 70, 68, 62, 82]),
    "Competitor E": np.array([84, 86, 55, 104, 122]),
}

# Rank labels shown on the blue bars
rank_labels = ["1 of 6", "2 of 6", "4 of 6", "6 of 6", "6 of 6"]

# Layout
n_cat = len(categories)
base_y = np.arange(n_cat)[::-1] * 2.0   # top to bottom
offsets = np.array([0.36, 0.18, 0.00, -0.18, -0.36])
bar_h = 0.16

fig, ax = plt.subplots(figsize=(10, 8))

# Competitor bars in gray
gray_shades = ["#bfbfbf", "#d9d9d9", "#a6a6a6", "#c9c9c9", "#8f8f8f"]
for i, (name, vals) in enumerate(competitors.items()):
    ax.barh(base_y + offsets[i], vals, height=bar_h, color=gray_shades[i], edgecolor="none")

# Our business in blue, slightly above center
blue = "#4C72B0"
ax.barh(base_y + 0.52, our_business, height=bar_h, color=blue, edgecolor="none")

# Category labels
for y, cat in zip(base_y, categories):
    ax.text(-4, y, cat, va="center", ha="right", fontsize=16, color="#333333")

# Rank labels on blue bars
for y, val, lab in zip(base_y + 0.52, our_business, rank_labels):
    ax.text(val + 2, y, lab, va="center", ha="left", fontsize=12, color=blue)

# Titles
ax.text(-4, base_y[0] + 1.7, "Performance overview", fontsize=22, weight="bold", color="#333333")
ax.text(4, base_y[0] + 0.95, "Weighted performance index | relative rank",
        fontsize=16, color="#555555")
ax.text(72, base_y[0] + 0.95, "relative rank", fontsize=16, color=blue)

# Legend-like labels on left
legend_items = [Patch(facecolor=blue, label="Our business")]
legend_items += [Patch(facecolor=gray_shades[i], label=name) for i, name in enumerate(competitors.keys())]
leg = ax.legend(
    handles=legend_items,
    frameon=False,
    loc="upper left",
    bbox_to_anchor=(-0.18, 0.92),
    fontsize=14,
    handlelength=0.6,
    handletextpad=0.4,
)
# Make "Our business" bold and blue
texts = leg.get_texts()
texts[0].set_color(blue)
texts[0].set_weight("bold")
for t in texts[1:]:
    t.set_color("#666666")

# Clean style
ax.set_xlim(0, 130)
ax.set_ylim(-1, base_y[0] + 2.2)
ax.set_xticks([])
ax.set_yticks([])
for spine in ax.spines.values():
    spine.set_visible(False)

plt.tight_layout()
plt.show()
